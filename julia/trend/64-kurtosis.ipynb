# %%
using StatsPlots, Distributions

# %%
# Generate data points for x-axis
x = range(-5, 5, length=1000)

# Calculate the corresponding y-values
# for the standard normal distribution
y_standard = pdf.(Normal(), x)
# Out:
# 1000-element Vector{Float64}:
#  1.4867195147342977e-6
#  1.5629451759545644e-6
#  1.6429143776209075e-6
#  1.7268022256027468e-6
#  1.8147915680031392e-6
#  1.9070733153312072e-6
#  2.0038467728640893e-6
#  2.1053199856146367e-6
#  2.211710096333239e-6
#  2.3232437169845253e-6
#  2.440157314152359e-6
#  2.5626976088394264e-6
#  2.6911219911409617e-6
#  ⋮
#  2.5626976088394264e-6
#  2.440157314152359e-6
#  2.3232437169845253e-6
#  2.211710096333239e-6
#  2.1053199856146367e-6
#  2.0038467728640893e-6
#  1.9070733153312072e-6
#  1.8147915680031392e-6
#  1.7268022256027468e-6
#  1.6429143776209075e-6
#  1.5629451759545644e-6
#  1.4867195147342977e-6

# %%
# Examples of distributions
# with different levels of kurtosis

# Standard normal distribution (Kurtosis = 0)
y_kurtosis_1 = pdf.(Normal(1, 1), x)

# Lower kurtosis
y_kurtosis_2 = pdf.(Normal(1, 0.5), x)

# Higher kurtosis
y_kurtosis_3 = pdf.(Normal(1, 2), x)
# Out:
# 1000-element Vector{Float64}:
#  0.0022159242059690038
#  0.0022494192126735245
#  0.002283363317102057
#  0.0023177615827983567
#  0.002352619115264551
#  0.002387941062077819
#  0.002423732613003513
#  0.0024599990001046663
#  0.002496745497847802
#  0.002533977423204968
#  0.002571700135751949
#  0.002609919037762559
#  0.002648639574298951
#  ⋮
#  0.030092144143616044
#  0.02980026128907287
#  0.029510470343311924
#  0.029222765411481676
#  0.028937140500129847
#  0.028653589518762197
#  0.028372106281398326
#  0.02809268450812413
#  0.027815317826640647
#  0.027539999773809297
#  0.027266723797193148
#  0.02699548325659403

# %%
# Plot the normal distribution and
# distributions with different levels of kurtosis
plot(
  x, y_standard, color=:black,
  label="Standard Normal",
  title = "Normal Distribution "
    * "with Different Kurtosis",
  xlabel = "x", ylabel = "Density",
)

# %%
plot!(
  x, y_kurtosis_1, color=:red,
  label="Standard Kurtosis = 0",
  linestyle=:dash, 
)

plot!(
  x, y_kurtosis_2, color=:green,
  label="Lower Kurtosis",
  linestyle=:dash, 
)

plot!(
  x, y_kurtosis_3, color=:blue,
  label="Higher Kurtosis",
  linestyle=:dash, 
)
