# %%
using StatsPlots, Distributions

# %%
# Generate data points for x-axis
x = range(-5, 5, length=1000)

# Calculate the corresponding y-values
# for the standard normal distribution
y_standard = pdf.(Normal(), x)
# Out:
# 1000-element Vector{Float64}:
#  1.4867195147342977e-6
#  1.5629451759545644e-6
#  1.6429143776209075e-6
#  1.7268022256027468e-6
#  1.8147915680031392e-6
#  1.9070733153312072e-6
#  2.0038467728640893e-6
#  2.1053199856146367e-6
#  2.211710096333239e-6
#  2.3232437169845253e-6
#  2.440157314152359e-6
#  2.5626976088394264e-6
#  2.6911219911409617e-6
#  ⋮
#  2.5626976088394264e-6
#  2.440157314152359e-6
#  2.3232437169845253e-6
#  2.211710096333239e-6
#  2.1053199856146367e-6
#  2.0038467728640893e-6
#  1.9070733153312072e-6
#  1.8147915680031392e-6
#  1.7268022256027468e-6
#  1.6429143776209075e-6
#  1.5629451759545644e-6
#  1.4867195147342977e-6

# %%
# Examples of distributions
# with different skewness parameters

# Negative skewness
y_skewed_1 = (2 * pdf.(Normal(), x) 
  .* cdf.(Normal(), x))

# Moderate positive skewness
y_skewed_2 = (2 * pdf.(Normal(), -x) 
  .* cdf.(Normal(), -x))

# High positive skewness
y_skewed_3 = (2 * pdf.(Normal(), x) 
  .* cdf.(Normal(), x) * 2)
# Out:
# 1000-element Vector{Float64}:
#  1.7046819433682338e-12
#  1.8874882862107145e-12
#  2.089486472621825e-12
#  2.3126465447220217e-12
#  2.5591359901340998e-12
#  2.8313390313175808e-12
#  3.131877748283964e-12
#  3.4636352038415625e-12
#  3.8297807556264905e-12
#  4.233797755584844e-12
#  4.679513855390486e-12
#  5.171134155626686e-12
#  5.713277457556767e-12
#  ⋮
#  1.025078526422355e-5
#  9.76062457709558e-6
#  9.292970634140346e-6
#  8.8468365555522e-6
#  8.421276478823344e-6
#  8.01538395957861e-6
#  7.6282904299857975e-6
#  7.259163712876567e-6
#  6.907206589764443e-6
#  6.5716554209971574e-6
#  6.251778816329971e-6
#  5.946876354255247e-6

# %%
# Plot the normal distribution
# and skewed distributions
plot(
  x, y_standard, color=:black,
label="Standard Normal",
  title = "Normal Distribution "
    * "with Different Skewness",
  xlabel = "x", ylabel = "Density",
)

# %%
plot!(
  x, y_skewed_1, color=:red,
  label="Negative Skewness = -4",
  linestyle=:dash,
)

plot!(
  x, y_skewed_2, color=:green,
  label="Moderate Positive Skewness = 2",
  linestyle=:dash,
)

plot!(
  x, y_skewed_3, color=:blue,
  label="High Positive Skewness = 6",
  linestyle=:dash,
)
